# %% [markdown]
# ### <font color='blue'>文分割</font>

# %% [markdown]
# 英文をどこで分割するかを決める。<br>
# ピリオド、疑問符などでそこで文が終了するかどうかを判断する。<br>

# %% [markdown]
# まずは文に分割されたデータを取得。<br>
# それを素性抽出に適した形に変換する。<br>

# %%
# ライブラリのインポート
import nltk

# %%
# 文のimport 
sents = nltk.corpus.treebank_raw.sents()

# %%
# 個々の文から取得されたトークンを１つにまとめる
tokens = []

# %%
# 文の境界となるトークンの添字番号を格納
boundaries = set()

# %%
offset = 0

# %%
# 文章から素性抽出器にかける際の情報を取得
for sent in sents:
    tokens.extend(sent) # 文字の追加
    offset += len(sent) # 文章の長さを足していく
    boundaries.add(offset-1) # 文書の長さの保存

# %%
len(tokens)
# Out:
# 101797

# %%
tokens[:20]
# Out:
# ['.',
#  'START',
#  'Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'will',
#  'join',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  'Nov',
#  '.',
#  '29']

# %% [markdown]
# 上記までで行なっていることは<br>
# まずはトークンをtokensリストに追加。<br>
# offsetに対して、これまでの文章の長さを足していく。<br>
# boundariesに対して、これまでの文章の長さを追加していく。<br>

# %% [markdown]
# 句読点記号が文の境界を意味しているかどうかを決定する。<br>

# %%
# 素性抽出器
def punct_features(tokens, i):
    return {'next-word-capitalized': tokens[i+1][0].isupper(), # 大文字
            'prev-word': tokens[i-1].lower(), # 小文字
            'punct': tokens[i], # どこに句読点が含まれているかどうか
            'prev-word-is-one-char': len(tokens[i-1]) == 1} # 前の単語が一文字かどうか

# %% [markdown]
# 上記の素性抽出器から、それらが文の境界を表すトークンかどうかをタグ付け。<br>

# %%
featuresets = [(punct_features(tokens, i), (i in boundaries))
               for i in range(1, len(tokens)-1)
               if tokens[i] in '.?!']

# %%
featuresets
# Out:
# [({'next-word-capitalized': False,
#    'prev-word': 'nov',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': '29',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'n',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'group',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'conglomerate',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'reported',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'corp',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': '1956',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'problem',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'story',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'properties',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'cigarettes',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'a',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'institute',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'dr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'university',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '1956',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '9',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'number',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'cancer',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'dr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'talcott',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'filters',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'dr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 't',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'medicine',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'dr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'explained',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'asbestos',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'outlawed',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '1950s',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'used',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'filters',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'area',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'vose',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'ago',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '."',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'rates',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '8',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '8',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'tuesday',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'year',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'period',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'sooner',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'days',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'rates',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '8',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '7',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'funds',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '1',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '352',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'billion',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'rates',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '9',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '9',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'earlier',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'yield',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '8',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '8',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '8',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '8',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '8',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '8',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': '%.',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'j',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'p',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'w',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'r',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '83',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'director',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'd',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'w',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'r',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'resigned',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'w',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'r',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'seats',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'corp',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'ltd',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'million',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'end',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'inc',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'p',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'a',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'million',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'industry',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'systems',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'million',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'debt',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '2',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '2',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'trillion',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'taxes',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '3',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'earliest',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'nov',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'then',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'j',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'corp',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'operations',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'corp',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'division',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'years',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'springs',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'year',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'meeting',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'owners',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'expand',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'factory',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'h',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'borge',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'followed',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'lights',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'guests',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'visitors',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'race',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'drivers',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'two',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'again',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'away',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'sauce',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'ovation',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'meetings',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'february',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'wednesday',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'economy',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '5',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '0',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '5',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'october',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'exports',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'billion',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'year',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '50',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'billion',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '50',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': '%.',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'advertisers',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'years',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'inc',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'b',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'report',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'january',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '980',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '7',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': '000',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'rates',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '1990',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '3',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'bureau',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'spoon',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'watches',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'recently',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '7',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'year',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '2',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': '%.',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'co',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'offer',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'co',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'company',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '2',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '2',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'worth',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'conn',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'n',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '2',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'billion',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'true',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'out',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'added',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'electric',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'attention',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'added',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'jr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'process',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '4',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '5',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'asserted',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'added',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'hampshire',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'court',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '3',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'trading',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'chain',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'm',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'r',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'board',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'co',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'plant',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'utility',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'period',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'feb',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'edison',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'pool',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'order',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'dec',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'year',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '1',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'share',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '737',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '3',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'share',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '38',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '12',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'cents',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '2',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': '1985',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'plant',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'illegal',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'expenses',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '3',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': '1986',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'interest',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'calculations',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'million',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'plant',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '2',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'end',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '72',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'plant',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'september',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'march',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '0',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'units',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '1988',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'devices',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'appliances',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'corp',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'cray',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'sheet',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'inc',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'scrapped',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'prototype',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'prospects',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'yesterday',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'interview',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'completed',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'september',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'scenario',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '2',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'trading',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '98',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'company',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'p',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'minneapolis',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'technology',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'equipment',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'supercomputer',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '1991',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'corp',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'corp',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'ltd',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'range',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'weeks',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'set',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'decide',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'nasdaq',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '4',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'share',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'earnings',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'spinoff',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '19',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': '5',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'posted',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '20',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'loss',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'research',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'year',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '000',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'messrs',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'm',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'a',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'r',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'hardware',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'research',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '1990',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'r',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'positions',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'officer',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'company',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'a',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'company',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'co',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'unit',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'd',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'edison',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'edison',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'p',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'utilities',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'president',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'rights',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'announced',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'spring',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mrs',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'issue',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'there',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mrs',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'pirates',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'films',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'films',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mrs',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'though',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'countries',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'list',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'arabia',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'u',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 's',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'law',
# ...
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'streets',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'tramp',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'person',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'matter',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'all',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'would',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'benign',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'cabs',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'hustlers',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'routine',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'to',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'home',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'carefree',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'man',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mother',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'curse',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'life',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'night',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'building',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'it',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'existence',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'force',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'voices',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'disagreeable',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'hypocrisy',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'traitor',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'woman',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'goodies',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'client',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'brief',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'home',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'person',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'off',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'revolution',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'victory',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'die',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'finest',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'co',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'jet',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'ltd',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'ltd',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'aircraft',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'program',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '1990s',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'event',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'country',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'content',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'stage',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'confrontational',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'themselves',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'city',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'voice',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'business',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'own',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'politicians',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'announcer',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'bullets',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'bullets',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'choice',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'truth',
#    'prev-word-is-one-char': False,
#    'punct': '?'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'nobody',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'accurate',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'job',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'it',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'incomplete',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'errors',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'kidnapping',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'members',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'reservations',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'lt',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'gov',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'force',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'generations',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'abortion',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'ad',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'ordeal',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'rapists',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'lawmakers',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'interrogation',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'college',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'hours',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'victims',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'rep',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'rep',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'courter',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'voice',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'business',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'grows',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'ailes',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'candidates',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'voice',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'land',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'grows',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ...]

# %%
size = int(len(featuresets) * 0.1)

# %%
# 訓練データとテストデータの作成
train_set, test_set = featuresets[size:], featuresets[:size]

# %%
# 学習器の訓練
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
# 精度を算出
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.936026936026936

# %% [markdown]
# この分類器を文分割に用いる。<br>

# %%
def segment_sentences(words):
    start = 0
    sents = []
    for i, word in enumerate(words):
        if word in '.?!' and classifier.classify(punct_features(words, i)) == True:
            sents.append(words[start:i+1])
            start = i+1
    if start < len(words):
        sents.append(words[start:])
    return sents

# %% [markdown]
# ### <font color='blue'>文分割についての素性抽出器についてみる</font>

# %%
# 文章
sents
# Out:
# [['.', 'START'], ['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.'], ...]

# %%
# 簡単な文章
temp_sents = sents[:20]

# %%
# 簡単な文章
temp_sents
# Out:
# [['.', 'START'],
#  ['Pierre',
#   'Vinken',
#   ',',
#   '61',
#   'years',
#   'old',
#   ',',
#   'will',
#   'join',
#   'the',
#   'board',
#   'as',
#   'a',
#   'nonexecutive',
#   'director',
#   'Nov',
#   '.',
#   '29',
#   '.'],
#  ['Mr',
#   '.',
#   'Vinken',
#   'is',
#   'chairman',
#   'of',
#   'Elsevier',
#   'N',
#   '.',
#   'V',
#   '.,',
#   'the',
#   'Dutch',
#   'publishing',
#   'group',
#   '.'],
#  ['.', 'START'],
#  ['Rudolph',
#   'Agnew',
#   ',',
#   '55',
#   'years',
#   'old',
#   'and',
#   'former',
#   'chairman',
#   'of',
#   'Consolidated',
#   'Gold',
#   'Fields',
#   'PLC',
#   ',',
#   'was',
#   'named',
#   'a',
#   'nonexecutive',
#   'director',
#   'of',
#   'this',
#   'British',
#   'industrial',
#   'conglomerate',
#   '.'],
#  ['.', 'START'],
#  ['A',
#   'form',
#   'of',
#   'asbestos',
#   'once',
#   'used',
#   'to',
#   'make',
#   'Kent',
#   'cigarette',
#   'filters',
#   'has',
#   'caused',
#   'a',
#   'high',
#   'percentage',
#   'of',
#   'cancer',
#   'deaths',
#   'among',
#   'a',
#   'group',
#   'of',
#   'workers',
#   'exposed',
#   'to',
#   'it',
#   'more',
#   'than',
#   '30',
#   'years',
#   'ago',
#   ',',
#   'researchers',
#   'reported',
#   '.'],
#  ['The',
#   'asbestos',
#   'fiber',
#   ',',
#   'crocidolite',
#   ',',
#   'is',
#   'unusually',
#   'resilient',
#   'once',
#   'it',
#   'enters',
#   'the',
#   'lungs',
#   ',',
#   'with',
#   'even',
#   'brief',
#   'exposures',
#   'to',
#   'it',
#   'causing',
#   'symptoms',
#   'that',
#   'show',
#   'up',
#   'decades',
#   'later',
#   ',',
#   'researchers',
#   'said',
#   '.'],
#  ['Lorillard',
#   'Inc',
#   '.,',
#   'the',
#   'unit',
#   'of',
#   'New',
#   'York',
#   '-',
#   'based',
#   'Loews',
#   'Corp',
#   '.',
#   'that',
#   'makes',
#   'Kent',
#   'cigarettes',
#   ',',
#   'stopped',
#   'using',
#   'crocidolite',
#   'in',
#   'its',
#   'Micronite',
#   'cigarette',
#   'filters',
#   'in',
#   '1956',
#   '.'],
#  ['Although',
#   'preliminary',
#   'findings',
#   'were',
#   'reported',
#   'more',
#   'than',
#   'a',
#   'year',
#   'ago',
#   ',',
#   'the',
#   'latest',
#   'results',
#   'appear',
#   'in',
#   'today',
#   "'",
#   's',
#   'New',
#   'England',
#   'Journal',
#   'of',
#   'Medicine',
#   ',',
#   'a',
#   'forum',
#   'likely',
#   'to',
#   'bring',
#   'new',
#   'attention',
#   'to',
#   'the',
#   'problem',
#   '.'],
#  ['A',
#   'Lorillard',
#   'spokewoman',
#   'said',
#   ',',
#   '"',
#   'This',
#   'is',
#   'an',
#   'old',
#   'story',
#   '.'],
#  ['We',
#   "'",
#   're',
#   'talking',
#   'about',
#   'years',
#   'ago',
#   'before',
#   'anyone',
#   'heard',
#   'of',
#   'asbestos',
#   'having',
#   'any',
#   'questionable',
#   'properties',
#   '.'],
#  ['There', 'is', 'no', 'asbestos', 'in', 'our', 'products', 'now', '."'],
#  ['Neither',
#   'Lorillard',
#   'nor',
#   'the',
#   'researchers',
#   'who',
#   'studied',
#   'the',
#   'workers',
#   'were',
#   'aware',
#   'of',
#   'any',
#   'research',
#   'on',
#   'smokers',
#   'of',
#   'the',
#   'Kent',
#   'cigarettes',
#   '.'],
#  ['"',
#   'We',
#   'have',
#   'no',
#   'useful',
#   'information',
#   'on',
#   'whether',
#   'users',
#   'are',
#   'at',
#   'risk',
#   ',"',
#   'said',
#   'James',
#   'A',
#   '.',
#   'Talcott',
#   'of',
#   'Boston',
#   "'",
#   's',
#   'Dana',
#   '-',
#   'Farber',
#   'Cancer',
#   'Institute',
#   '.'],
#  ['Dr',
#   '.',
#   'Talcott',
#   'led',
#   'a',
#   'team',
#   'of',
#   'researchers',
#   'from',
#   'the',
#   'National',
#   'Cancer',
#   'Institute',
#   'and',
#   'the',
#   'medical',
#   'schools',
#   'of',
#   'Harvard',
#   'University',
#   'and',
#   'Boston',
#   'University',
#   '.'],
#  ['The',
#   'Lorillard',
#   'spokeswoman',
#   'said',
#   'asbestos',
#   'was',
#   'used',
#   'in',
#   '"',
#   'very',
#   'modest',
#   'amounts',
#   '"',
#   'in',
#   'making',
#   'paper',
#   'for',
#   'the',
#   'filters',
#   'in',
#   'the',
#   'early',
#   '1950s',
#   'and',
#   'replaced',
#   'with',
#   'a',
#   'different',
#   'type',
#   'of',
#   'filter',
#   'in',
#   '1956',
#   '.'],
#  ['From',
#   '1953',
#   'to',
#   '1955',
#   ',',
#   '9',
#   '.',
#   '8',
#   'billion',
#   'Kent',
#   'cigarettes',
#   'with',
#   'the',
#   'filters',
#   'were',
#   'sold',
#   ',',
#   'the',
#   'company',
#   'said',
#   '.'],
#  ['Among',
#   '33',
#   'men',
#   'who',
#   'worked',
#   'closely',
#   'with',
#   'the',
#   'substance',
#   ',',
#   '28',
#   'have',
#   'died',
#   '--',
#   'more',
#   'than',
#   'three',
#   'times',
#   'the',
#   'expected',
#   'number',
#   '.'],
#  ['Four',
#   'of',
#   'the',
#   'five',
#   'surviving',
#   'workers',
#   'have',
#   'asbestos',
#   '-',
#   'related',
#   'diseases',
#   ',',
#   'including',
#   'three',
#   'with',
#   'recently',
#   'diagnosed',
#   'cancer',
#   '.']]

# %%
# 初期化
tokens = list()
offset = 0
boundaries =  set()

# 文章から素性抽出器にかける際の情報を取得
for sent in temp_sents:
    tokens.extend(sent) # トークンの追加
    print('tokens : '+str(tokens))
    print('')
    offset += len(sent) # 文章の長さを足していく
    print('offset : '+str(offset))
    print('')
    boundaries.add(offset-1) # temp_sentsの、各文書の長さを保存
    print('boundaries : '+str(boundaries))
    print('')
# Out:
# tokens : ['.', 'START']
#
# offset : 2
#
# boundaries : {1}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.']
#
# offset : 21
#
# boundaries : {1, 20}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.']
#
# offset : 37
#
# boundaries : {1, 20, 36}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START']
#
# offset : 39
#
# boundaries : {38, 1, 20, 36}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.']
#
# offset : 65
#
# boundaries : {64, 1, 36, 38, 20}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START']
#
# offset : 67
#
# boundaries : {64, 1, 66, 36, 38, 20}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START', 'A', 'form', 'of', 'asbestos', 'once', 'used', 'to', 'make', 'Kent', 'cigarette', 'filters', 'has', 'caused', 'a', 'high', 'percentage', 'of', 'cancer', 'deaths', 'among', 'a', 'group', 'of', 'workers', 'exposed', 'to', 'it', 'more', 'than', '30', 'years', 'ago', ',', 'researchers', 'reported', '.']
#
# offset : 103
#
# boundaries : {64, 1, 66, 36, 38, 102, 20}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START', 'A', 'form', 'of', 'asbestos', 'once', 'used', 'to', 'make', 'Kent', 'cigarette', 'filters', 'has', 'caused', 'a', 'high', 'percentage', 'of', 'cancer', 'deaths', 'among', 'a', 'group', 'of', 'workers', 'exposed', 'to', 'it', 'more', 'than', '30', 'years', 'ago', ',', 'researchers', 'reported', '.', 'The', 'asbestos', 'fiber', ',', 'crocidolite', ',', 'is', 'unusually', 'resilient', 'once', 'it', 'enters', 'the', 'lungs', ',', 'with', 'even', 'brief', 'exposures', 'to', 'it', 'causing', 'symptoms', 'that', 'show', 'up', 'decades', 'later', ',', 'researchers', 'said', '.']
#
# offset : 135
#
# boundaries : {64, 1, 66, 36, 38, 102, 134, 20}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START', 'A', 'form', 'of', 'asbestos', 'once', 'used', 'to', 'make', 'Kent', 'cigarette', 'filters', 'has', 'caused', 'a', 'high', 'percentage', 'of', 'cancer', 'deaths', 'among', 'a', 'group', 'of', 'workers', 'exposed', 'to', 'it', 'more', 'than', '30', 'years', 'ago', ',', 'researchers', 'reported', '.', 'The', 'asbestos', 'fiber', ',', 'crocidolite', ',', 'is', 'unusually', 'resilient', 'once', 'it', 'enters', 'the', 'lungs', ',', 'with', 'even', 'brief', 'exposures', 'to', 'it', 'causing', 'symptoms', 'that', 'show', 'up', 'decades', 'later', ',', 'researchers', 'said', '.', 'Lorillard', 'Inc', '.,', 'the', 'unit', 'of', 'New', 'York', '-', 'based', 'Loews', 'Corp', '.', 'that', 'makes', 'Kent', 'cigarettes', ',', 'stopped', 'using', 'crocidolite', 'in', 'its', 'Micronite', 'cigarette', 'filters', 'in', '1956', '.']
#
# offset : 164
#
# boundaries : {64, 1, 66, 163, 36, 38, 102, 134, 20}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START', 'A', 'form', 'of', 'asbestos', 'once', 'used', 'to', 'make', 'Kent', 'cigarette', 'filters', 'has', 'caused', 'a', 'high', 'percentage', 'of', 'cancer', 'deaths', 'among', 'a', 'group', 'of', 'workers', 'exposed', 'to', 'it', 'more', 'than', '30', 'years', 'ago', ',', 'researchers', 'reported', '.', 'The', 'asbestos', 'fiber', ',', 'crocidolite', ',', 'is', 'unusually', 'resilient', 'once', 'it', 'enters', 'the', 'lungs', ',', 'with', 'even', 'brief', 'exposures', 'to', 'it', 'causing', 'symptoms', 'that', 'show', 'up', 'decades', 'later', ',', 'researchers', 'said', '.', 'Lorillard', 'Inc', '.,', 'the', 'unit', 'of', 'New', 'York', '-', 'based', 'Loews', 'Corp', '.', 'that', 'makes', 'Kent', 'cigarettes', ',', 'stopped', 'using', 'crocidolite', 'in', 'its', 'Micronite', 'cigarette', 'filters', 'in', '1956', '.', 'Although', 'preliminary', 'findings', 'were', 'reported', 'more', 'than', 'a', 'year', 'ago', ',', 'the', 'latest', 'results', 'appear', 'in', 'today', "'", 's', 'New', 'England', 'Journal', 'of', 'Medicine', ',', 'a', 'forum', 'likely', 'to', 'bring', 'new', 'attention', 'to', 'the', 'problem', '.']
#
# offset : 200
#
# boundaries : {64, 1, 66, 163, 36, 38, 102, 134, 199, 20}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START', 'A', 'form', 'of', 'asbestos', 'once', 'used', 'to', 'make', 'Kent', 'cigarette', 'filters', 'has', 'caused', 'a', 'high', 'percentage', 'of', 'cancer', 'deaths', 'among', 'a', 'group', 'of', 'workers', 'exposed', 'to', 'it', 'more', 'than', '30', 'years', 'ago', ',', 'researchers', 'reported', '.', 'The', 'asbestos', 'fiber', ',', 'crocidolite', ',', 'is', 'unusually', 'resilient', 'once', 'it', 'enters', 'the', 'lungs', ',', 'with', 'even', 'brief', 'exposures', 'to', 'it', 'causing', 'symptoms', 'that', 'show', 'up', 'decades', 'later', ',', 'researchers', 'said', '.', 'Lorillard', 'Inc', '.,', 'the', 'unit', 'of', 'New', 'York', '-', 'based', 'Loews', 'Corp', '.', 'that', 'makes', 'Kent', 'cigarettes', ',', 'stopped', 'using', 'crocidolite', 'in', 'its', 'Micronite', 'cigarette', 'filters', 'in', '1956', '.', 'Although', 'preliminary', 'findings', 'were', 'reported', 'more', 'than', 'a', 'year', 'ago', ',', 'the', 'latest', 'results', 'appear', 'in', 'today', "'", 's', 'New', 'England', 'Journal', 'of', 'Medicine', ',', 'a', 'forum', 'likely', 'to', 'bring', 'new', 'attention', 'to', 'the', 'problem', '.', 'A', 'Lorillard', 'spokewoman', 'said', ',', '"', 'This', 'is', 'an', 'old', 'story', '.']
#
# offset : 212
#
# boundaries : {64, 1, 66, 163, 36, 38, 102, 134, 199, 211, 20}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START', 'A', 'form', 'of', 'asbestos', 'once', 'used', 'to', 'make', 'Kent', 'cigarette', 'filters', 'has', 'caused', 'a', 'high', 'percentage', 'of', 'cancer', 'deaths', 'among', 'a', 'group', 'of', 'workers', 'exposed', 'to', 'it', 'more', 'than', '30', 'years', 'ago', ',', 'researchers', 'reported', '.', 'The', 'asbestos', 'fiber', ',', 'crocidolite', ',', 'is', 'unusually', 'resilient', 'once', 'it', 'enters', 'the', 'lungs', ',', 'with', 'even', 'brief', 'exposures', 'to', 'it', 'causing', 'symptoms', 'that', 'show', 'up', 'decades', 'later', ',', 'researchers', 'said', '.', 'Lorillard', 'Inc', '.,', 'the', 'unit', 'of', 'New', 'York', '-', 'based', 'Loews', 'Corp', '.', 'that', 'makes', 'Kent', 'cigarettes', ',', 'stopped', 'using', 'crocidolite', 'in', 'its', 'Micronite', 'cigarette', 'filters', 'in', '1956', '.', 'Although', 'preliminary', 'findings', 'were', 'reported', 'more', 'than', 'a', 'year', 'ago', ',', 'the', 'latest', 'results', 'appear', 'in', 'today', "'", 's', 'New', 'England', 'Journal', 'of', 'Medicine', ',', 'a', 'forum', 'likely', 'to', 'bring', 'new', 'attention', 'to', 'the', 'problem', '.', 'A', 'Lorillard', 'spokewoman', 'said', ',', '"', 'This', 'is', 'an', 'old', 'story', '.', 'We', "'", 're', 'talking', 'about', 'years', 'ago', 'before', 'anyone', 'heard', 'of', 'asbestos', 'having', 'any', 'questionable', 'properties', '.']
#
# offset : 229
#
# boundaries : {64, 1, 66, 163, 36, 228, 38, 102, 134, 199, 211, 20}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START', 'A', 'form', 'of', 'asbestos', 'once', 'used', 'to', 'make', 'Kent', 'cigarette', 'filters', 'has', 'caused', 'a', 'high', 'percentage', 'of', 'cancer', 'deaths', 'among', 'a', 'group', 'of', 'workers', 'exposed', 'to', 'it', 'more', 'than', '30', 'years', 'ago', ',', 'researchers', 'reported', '.', 'The', 'asbestos', 'fiber', ',', 'crocidolite', ',', 'is', 'unusually', 'resilient', 'once', 'it', 'enters', 'the', 'lungs', ',', 'with', 'even', 'brief', 'exposures', 'to', 'it', 'causing', 'symptoms', 'that', 'show', 'up', 'decades', 'later', ',', 'researchers', 'said', '.', 'Lorillard', 'Inc', '.,', 'the', 'unit', 'of', 'New', 'York', '-', 'based', 'Loews', 'Corp', '.', 'that', 'makes', 'Kent', 'cigarettes', ',', 'stopped', 'using', 'crocidolite', 'in', 'its', 'Micronite', 'cigarette', 'filters', 'in', '1956', '.', 'Although', 'preliminary', 'findings', 'were', 'reported', 'more', 'than', 'a', 'year', 'ago', ',', 'the', 'latest', 'results', 'appear', 'in', 'today', "'", 's', 'New', 'England', 'Journal', 'of', 'Medicine', ',', 'a', 'forum', 'likely', 'to', 'bring', 'new', 'attention', 'to', 'the', 'problem', '.', 'A', 'Lorillard', 'spokewoman', 'said', ',', '"', 'This', 'is', 'an', 'old', 'story', '.', 'We', "'", 're', 'talking', 'about', 'years', 'ago', 'before', 'anyone', 'heard', 'of', 'asbestos', 'having', 'any', 'questionable', 'properties', '.', 'There', 'is', 'no', 'asbestos', 'in', 'our', 'products', 'now', '."']
#
# offset : 238
#
# boundaries : {64, 1, 66, 163, 36, 228, 38, 102, 134, 199, 237, 211, 20}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START', 'A', 'form', 'of', 'asbestos', 'once', 'used', 'to', 'make', 'Kent', 'cigarette', 'filters', 'has', 'caused', 'a', 'high', 'percentage', 'of', 'cancer', 'deaths', 'among', 'a', 'group', 'of', 'workers', 'exposed', 'to', 'it', 'more', 'than', '30', 'years', 'ago', ',', 'researchers', 'reported', '.', 'The', 'asbestos', 'fiber', ',', 'crocidolite', ',', 'is', 'unusually', 'resilient', 'once', 'it', 'enters', 'the', 'lungs', ',', 'with', 'even', 'brief', 'exposures', 'to', 'it', 'causing', 'symptoms', 'that', 'show', 'up', 'decades', 'later', ',', 'researchers', 'said', '.', 'Lorillard', 'Inc', '.,', 'the', 'unit', 'of', 'New', 'York', '-', 'based', 'Loews', 'Corp', '.', 'that', 'makes', 'Kent', 'cigarettes', ',', 'stopped', 'using', 'crocidolite', 'in', 'its', 'Micronite', 'cigarette', 'filters', 'in', '1956', '.', 'Although', 'preliminary', 'findings', 'were', 'reported', 'more', 'than', 'a', 'year', 'ago', ',', 'the', 'latest', 'results', 'appear', 'in', 'today', "'", 's', 'New', 'England', 'Journal', 'of', 'Medicine', ',', 'a', 'forum', 'likely', 'to', 'bring', 'new', 'attention', 'to', 'the', 'problem', '.', 'A', 'Lorillard', 'spokewoman', 'said', ',', '"', 'This', 'is', 'an', 'old', 'story', '.', 'We', "'", 're', 'talking', 'about', 'years', 'ago', 'before', 'anyone', 'heard', 'of', 'asbestos', 'having', 'any', 'questionable', 'properties', '.', 'There', 'is', 'no', 'asbestos', 'in', 'our', 'products', 'now', '."', 'Neither', 'Lorillard', 'nor', 'the', 'researchers', 'who', 'studied', 'the', 'workers', 'were', 'aware', 'of', 'any', 'research', 'on', 'smokers', 'of', 'the', 'Kent', 'cigarettes', '.']
#
# offset : 259
#
# boundaries : {64, 1, 66, 163, 36, 228, 38, 102, 134, 199, 258, 237, 211, 20}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START', 'A', 'form', 'of', 'asbestos', 'once', 'used', 'to', 'make', 'Kent', 'cigarette', 'filters', 'has', 'caused', 'a', 'high', 'percentage', 'of', 'cancer', 'deaths', 'among', 'a', 'group', 'of', 'workers', 'exposed', 'to', 'it', 'more', 'than', '30', 'years', 'ago', ',', 'researchers', 'reported', '.', 'The', 'asbestos', 'fiber', ',', 'crocidolite', ',', 'is', 'unusually', 'resilient', 'once', 'it', 'enters', 'the', 'lungs', ',', 'with', 'even', 'brief', 'exposures', 'to', 'it', 'causing', 'symptoms', 'that', 'show', 'up', 'decades', 'later', ',', 'researchers', 'said', '.', 'Lorillard', 'Inc', '.,', 'the', 'unit', 'of', 'New', 'York', '-', 'based', 'Loews', 'Corp', '.', 'that', 'makes', 'Kent', 'cigarettes', ',', 'stopped', 'using', 'crocidolite', 'in', 'its', 'Micronite', 'cigarette', 'filters', 'in', '1956', '.', 'Although', 'preliminary', 'findings', 'were', 'reported', 'more', 'than', 'a', 'year', 'ago', ',', 'the', 'latest', 'results', 'appear', 'in', 'today', "'", 's', 'New', 'England', 'Journal', 'of', 'Medicine', ',', 'a', 'forum', 'likely', 'to', 'bring', 'new', 'attention', 'to', 'the', 'problem', '.', 'A', 'Lorillard', 'spokewoman', 'said', ',', '"', 'This', 'is', 'an', 'old', 'story', '.', 'We', "'", 're', 'talking', 'about', 'years', 'ago', 'before', 'anyone', 'heard', 'of', 'asbestos', 'having', 'any', 'questionable', 'properties', '.', 'There', 'is', 'no', 'asbestos', 'in', 'our', 'products', 'now', '."', 'Neither', 'Lorillard', 'nor', 'the', 'researchers', 'who', 'studied', 'the', 'workers', 'were', 'aware', 'of', 'any', 'research', 'on', 'smokers', 'of', 'the', 'Kent', 'cigarettes', '.', '"', 'We', 'have', 'no', 'useful', 'information', 'on', 'whether', 'users', 'are', 'at', 'risk', ',"', 'said', 'James', 'A', '.', 'Talcott', 'of', 'Boston', "'", 's', 'Dana', '-', 'Farber', 'Cancer', 'Institute', '.']
#
# offset : 287
#
# boundaries : {64, 1, 66, 163, 36, 228, 38, 102, 134, 199, 258, 237, 211, 20, 286}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START', 'A', 'form', 'of', 'asbestos', 'once', 'used', 'to', 'make', 'Kent', 'cigarette', 'filters', 'has', 'caused', 'a', 'high', 'percentage', 'of', 'cancer', 'deaths', 'among', 'a', 'group', 'of', 'workers', 'exposed', 'to', 'it', 'more', 'than', '30', 'years', 'ago', ',', 'researchers', 'reported', '.', 'The', 'asbestos', 'fiber', ',', 'crocidolite', ',', 'is', 'unusually', 'resilient', 'once', 'it', 'enters', 'the', 'lungs', ',', 'with', 'even', 'brief', 'exposures', 'to', 'it', 'causing', 'symptoms', 'that', 'show', 'up', 'decades', 'later', ',', 'researchers', 'said', '.', 'Lorillard', 'Inc', '.,', 'the', 'unit', 'of', 'New', 'York', '-', 'based', 'Loews', 'Corp', '.', 'that', 'makes', 'Kent', 'cigarettes', ',', 'stopped', 'using', 'crocidolite', 'in', 'its', 'Micronite', 'cigarette', 'filters', 'in', '1956', '.', 'Although', 'preliminary', 'findings', 'were', 'reported', 'more', 'than', 'a', 'year', 'ago', ',', 'the', 'latest', 'results', 'appear', 'in', 'today', "'", 's', 'New', 'England', 'Journal', 'of', 'Medicine', ',', 'a', 'forum', 'likely', 'to', 'bring', 'new', 'attention', 'to', 'the', 'problem', '.', 'A', 'Lorillard', 'spokewoman', 'said', ',', '"', 'This', 'is', 'an', 'old', 'story', '.', 'We', "'", 're', 'talking', 'about', 'years', 'ago', 'before', 'anyone', 'heard', 'of', 'asbestos', 'having', 'any', 'questionable', 'properties', '.', 'There', 'is', 'no', 'asbestos', 'in', 'our', 'products', 'now', '."', 'Neither', 'Lorillard', 'nor', 'the', 'researchers', 'who', 'studied', 'the', 'workers', 'were', 'aware', 'of', 'any', 'research', 'on', 'smokers', 'of', 'the', 'Kent', 'cigarettes', '.', '"', 'We', 'have', 'no', 'useful', 'information', 'on', 'whether', 'users', 'are', 'at', 'risk', ',"', 'said', 'James', 'A', '.', 'Talcott', 'of', 'Boston', "'", 's', 'Dana', '-', 'Farber', 'Cancer', 'Institute', '.', 'Dr', '.', 'Talcott', 'led', 'a', 'team', 'of', 'researchers', 'from', 'the', 'National', 'Cancer', 'Institute', 'and', 'the', 'medical', 'schools', 'of', 'Harvard', 'University', 'and', 'Boston', 'University', '.']
#
# offset : 311
#
# boundaries : {64, 1, 66, 163, 36, 228, 38, 102, 134, 199, 258, 237, 211, 20, 310, 286}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START', 'A', 'form', 'of', 'asbestos', 'once', 'used', 'to', 'make', 'Kent', 'cigarette', 'filters', 'has', 'caused', 'a', 'high', 'percentage', 'of', 'cancer', 'deaths', 'among', 'a', 'group', 'of', 'workers', 'exposed', 'to', 'it', 'more', 'than', '30', 'years', 'ago', ',', 'researchers', 'reported', '.', 'The', 'asbestos', 'fiber', ',', 'crocidolite', ',', 'is', 'unusually', 'resilient', 'once', 'it', 'enters', 'the', 'lungs', ',', 'with', 'even', 'brief', 'exposures', 'to', 'it', 'causing', 'symptoms', 'that', 'show', 'up', 'decades', 'later', ',', 'researchers', 'said', '.', 'Lorillard', 'Inc', '.,', 'the', 'unit', 'of', 'New', 'York', '-', 'based', 'Loews', 'Corp', '.', 'that', 'makes', 'Kent', 'cigarettes', ',', 'stopped', 'using', 'crocidolite', 'in', 'its', 'Micronite', 'cigarette', 'filters', 'in', '1956', '.', 'Although', 'preliminary', 'findings', 'were', 'reported', 'more', 'than', 'a', 'year', 'ago', ',', 'the', 'latest', 'results', 'appear', 'in', 'today', "'", 's', 'New', 'England', 'Journal', 'of', 'Medicine', ',', 'a', 'forum', 'likely', 'to', 'bring', 'new', 'attention', 'to', 'the', 'problem', '.', 'A', 'Lorillard', 'spokewoman', 'said', ',', '"', 'This', 'is', 'an', 'old', 'story', '.', 'We', "'", 're', 'talking', 'about', 'years', 'ago', 'before', 'anyone', 'heard', 'of', 'asbestos', 'having', 'any', 'questionable', 'properties', '.', 'There', 'is', 'no', 'asbestos', 'in', 'our', 'products', 'now', '."', 'Neither', 'Lorillard', 'nor', 'the', 'researchers', 'who', 'studied', 'the', 'workers', 'were', 'aware', 'of', 'any', 'research', 'on', 'smokers', 'of', 'the', 'Kent', 'cigarettes', '.', '"', 'We', 'have', 'no', 'useful', 'information', 'on', 'whether', 'users', 'are', 'at', 'risk', ',"', 'said', 'James', 'A', '.', 'Talcott', 'of', 'Boston', "'", 's', 'Dana', '-', 'Farber', 'Cancer', 'Institute', '.', 'Dr', '.', 'Talcott', 'led', 'a', 'team', 'of', 'researchers', 'from', 'the', 'National', 'Cancer', 'Institute', 'and', 'the', 'medical', 'schools', 'of', 'Harvard', 'University', 'and', 'Boston', 'University', '.', 'The', 'Lorillard', 'spokeswoman', 'said', 'asbestos', 'was', 'used', 'in', '"', 'very', 'modest', 'amounts', '"', 'in', 'making', 'paper', 'for', 'the', 'filters', 'in', 'the', 'early', '1950s', 'and', 'replaced', 'with', 'a', 'different', 'type', 'of', 'filter', 'in', '1956', '.']
#
# offset : 345
#
# boundaries : {64, 1, 66, 163, 36, 228, 38, 102, 134, 199, 258, 237, 211, 20, 310, 344, 286}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START', 'A', 'form', 'of', 'asbestos', 'once', 'used', 'to', 'make', 'Kent', 'cigarette', 'filters', 'has', 'caused', 'a', 'high', 'percentage', 'of', 'cancer', 'deaths', 'among', 'a', 'group', 'of', 'workers', 'exposed', 'to', 'it', 'more', 'than', '30', 'years', 'ago', ',', 'researchers', 'reported', '.', 'The', 'asbestos', 'fiber', ',', 'crocidolite', ',', 'is', 'unusually', 'resilient', 'once', 'it', 'enters', 'the', 'lungs', ',', 'with', 'even', 'brief', 'exposures', 'to', 'it', 'causing', 'symptoms', 'that', 'show', 'up', 'decades', 'later', ',', 'researchers', 'said', '.', 'Lorillard', 'Inc', '.,', 'the', 'unit', 'of', 'New', 'York', '-', 'based', 'Loews', 'Corp', '.', 'that', 'makes', 'Kent', 'cigarettes', ',', 'stopped', 'using', 'crocidolite', 'in', 'its', 'Micronite', 'cigarette', 'filters', 'in', '1956', '.', 'Although', 'preliminary', 'findings', 'were', 'reported', 'more', 'than', 'a', 'year', 'ago', ',', 'the', 'latest', 'results', 'appear', 'in', 'today', "'", 's', 'New', 'England', 'Journal', 'of', 'Medicine', ',', 'a', 'forum', 'likely', 'to', 'bring', 'new', 'attention', 'to', 'the', 'problem', '.', 'A', 'Lorillard', 'spokewoman', 'said', ',', '"', 'This', 'is', 'an', 'old', 'story', '.', 'We', "'", 're', 'talking', 'about', 'years', 'ago', 'before', 'anyone', 'heard', 'of', 'asbestos', 'having', 'any', 'questionable', 'properties', '.', 'There', 'is', 'no', 'asbestos', 'in', 'our', 'products', 'now', '."', 'Neither', 'Lorillard', 'nor', 'the', 'researchers', 'who', 'studied', 'the', 'workers', 'were', 'aware', 'of', 'any', 'research', 'on', 'smokers', 'of', 'the', 'Kent', 'cigarettes', '.', '"', 'We', 'have', 'no', 'useful', 'information', 'on', 'whether', 'users', 'are', 'at', 'risk', ',"', 'said', 'James', 'A', '.', 'Talcott', 'of', 'Boston', "'", 's', 'Dana', '-', 'Farber', 'Cancer', 'Institute', '.', 'Dr', '.', 'Talcott', 'led', 'a', 'team', 'of', 'researchers', 'from', 'the', 'National', 'Cancer', 'Institute', 'and', 'the', 'medical', 'schools', 'of', 'Harvard', 'University', 'and', 'Boston', 'University', '.', 'The', 'Lorillard', 'spokeswoman', 'said', 'asbestos', 'was', 'used', 'in', '"', 'very', 'modest', 'amounts', '"', 'in', 'making', 'paper', 'for', 'the', 'filters', 'in', 'the', 'early', '1950s', 'and', 'replaced', 'with', 'a', 'different', 'type', 'of', 'filter', 'in', '1956', '.', 'From', '1953', 'to', '1955', ',', '9', '.', '8', 'billion', 'Kent', 'cigarettes', 'with', 'the', 'filters', 'were', 'sold', ',', 'the', 'company', 'said', '.']
#
# offset : 366
#
# boundaries : {64, 1, 66, 163, 36, 228, 38, 102, 134, 199, 258, 237, 365, 211, 20, 310, 344, 286}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START', 'A', 'form', 'of', 'asbestos', 'once', 'used', 'to', 'make', 'Kent', 'cigarette', 'filters', 'has', 'caused', 'a', 'high', 'percentage', 'of', 'cancer', 'deaths', 'among', 'a', 'group', 'of', 'workers', 'exposed', 'to', 'it', 'more', 'than', '30', 'years', 'ago', ',', 'researchers', 'reported', '.', 'The', 'asbestos', 'fiber', ',', 'crocidolite', ',', 'is', 'unusually', 'resilient', 'once', 'it', 'enters', 'the', 'lungs', ',', 'with', 'even', 'brief', 'exposures', 'to', 'it', 'causing', 'symptoms', 'that', 'show', 'up', 'decades', 'later', ',', 'researchers', 'said', '.', 'Lorillard', 'Inc', '.,', 'the', 'unit', 'of', 'New', 'York', '-', 'based', 'Loews', 'Corp', '.', 'that', 'makes', 'Kent', 'cigarettes', ',', 'stopped', 'using', 'crocidolite', 'in', 'its', 'Micronite', 'cigarette', 'filters', 'in', '1956', '.', 'Although', 'preliminary', 'findings', 'were', 'reported', 'more', 'than', 'a', 'year', 'ago', ',', 'the', 'latest', 'results', 'appear', 'in', 'today', "'", 's', 'New', 'England', 'Journal', 'of', 'Medicine', ',', 'a', 'forum', 'likely', 'to', 'bring', 'new', 'attention', 'to', 'the', 'problem', '.', 'A', 'Lorillard', 'spokewoman', 'said', ',', '"', 'This', 'is', 'an', 'old', 'story', '.', 'We', "'", 're', 'talking', 'about', 'years', 'ago', 'before', 'anyone', 'heard', 'of', 'asbestos', 'having', 'any', 'questionable', 'properties', '.', 'There', 'is', 'no', 'asbestos', 'in', 'our', 'products', 'now', '."', 'Neither', 'Lorillard', 'nor', 'the', 'researchers', 'who', 'studied', 'the', 'workers', 'were', 'aware', 'of', 'any', 'research', 'on', 'smokers', 'of', 'the', 'Kent', 'cigarettes', '.', '"', 'We', 'have', 'no', 'useful', 'information', 'on', 'whether', 'users', 'are', 'at', 'risk', ',"', 'said', 'James', 'A', '.', 'Talcott', 'of', 'Boston', "'", 's', 'Dana', '-', 'Farber', 'Cancer', 'Institute', '.', 'Dr', '.', 'Talcott', 'led', 'a', 'team', 'of', 'researchers', 'from', 'the', 'National', 'Cancer', 'Institute', 'and', 'the', 'medical', 'schools', 'of', 'Harvard', 'University', 'and', 'Boston', 'University', '.', 'The', 'Lorillard', 'spokeswoman', 'said', 'asbestos', 'was', 'used', 'in', '"', 'very', 'modest', 'amounts', '"', 'in', 'making', 'paper', 'for', 'the', 'filters', 'in', 'the', 'early', '1950s', 'and', 'replaced', 'with', 'a', 'different', 'type', 'of', 'filter', 'in', '1956', '.', 'From', '1953', 'to', '1955', ',', '9', '.', '8', 'billion', 'Kent', 'cigarettes', 'with', 'the', 'filters', 'were', 'sold', ',', 'the', 'company', 'said', '.', 'Among', '33', 'men', 'who', 'worked', 'closely', 'with', 'the', 'substance', ',', '28', 'have', 'died', '--', 'more', 'than', 'three', 'times', 'the', 'expected', 'number', '.']
#
# offset : 388
#
# boundaries : {64, 1, 66, 163, 36, 228, 38, 102, 134, 199, 258, 387, 237, 365, 211, 20, 310, 344, 286}
#
# tokens : ['.', 'START', 'Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov', '.', '29', '.', 'Mr', '.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N', '.', 'V', '.,', 'the', 'Dutch', 'publishing', 'group', '.', '.', 'START', 'Rudolph', 'Agnew', ',', '55', 'years', 'old', 'and', 'former', 'chairman', 'of', 'Consolidated', 'Gold', 'Fields', 'PLC', ',', 'was', 'named', 'a', 'nonexecutive', 'director', 'of', 'this', 'British', 'industrial', 'conglomerate', '.', '.', 'START', 'A', 'form', 'of', 'asbestos', 'once', 'used', 'to', 'make', 'Kent', 'cigarette', 'filters', 'has', 'caused', 'a', 'high', 'percentage', 'of', 'cancer', 'deaths', 'among', 'a', 'group', 'of', 'workers', 'exposed', 'to', 'it', 'more', 'than', '30', 'years', 'ago', ',', 'researchers', 'reported', '.', 'The', 'asbestos', 'fiber', ',', 'crocidolite', ',', 'is', 'unusually', 'resilient', 'once', 'it', 'enters', 'the', 'lungs', ',', 'with', 'even', 'brief', 'exposures', 'to', 'it', 'causing', 'symptoms', 'that', 'show', 'up', 'decades', 'later', ',', 'researchers', 'said', '.', 'Lorillard', 'Inc', '.,', 'the', 'unit', 'of', 'New', 'York', '-', 'based', 'Loews', 'Corp', '.', 'that', 'makes', 'Kent', 'cigarettes', ',', 'stopped', 'using', 'crocidolite', 'in', 'its', 'Micronite', 'cigarette', 'filters', 'in', '1956', '.', 'Although', 'preliminary', 'findings', 'were', 'reported', 'more', 'than', 'a', 'year', 'ago', ',', 'the', 'latest', 'results', 'appear', 'in', 'today', "'", 's', 'New', 'England', 'Journal', 'of', 'Medicine', ',', 'a', 'forum', 'likely', 'to', 'bring', 'new', 'attention', 'to', 'the', 'problem', '.', 'A', 'Lorillard', 'spokewoman', 'said', ',', '"', 'This', 'is', 'an', 'old', 'story', '.', 'We', "'", 're', 'talking', 'about', 'years', 'ago', 'before', 'anyone', 'heard', 'of', 'asbestos', 'having', 'any', 'questionable', 'properties', '.', 'There', 'is', 'no', 'asbestos', 'in', 'our', 'products', 'now', '."', 'Neither', 'Lorillard', 'nor', 'the', 'researchers', 'who', 'studied', 'the', 'workers', 'were', 'aware', 'of', 'any', 'research', 'on', 'smokers', 'of', 'the', 'Kent', 'cigarettes', '.', '"', 'We', 'have', 'no', 'useful', 'information', 'on', 'whether', 'users', 'are', 'at', 'risk', ',"', 'said', 'James', 'A', '.', 'Talcott', 'of', 'Boston', "'", 's', 'Dana', '-', 'Farber', 'Cancer', 'Institute', '.', 'Dr', '.', 'Talcott', 'led', 'a', 'team', 'of', 'researchers', 'from', 'the', 'National', 'Cancer', 'Institute', 'and', 'the', 'medical', 'schools', 'of', 'Harvard', 'University', 'and', 'Boston', 'University', '.', 'The', 'Lorillard', 'spokeswoman', 'said', 'asbestos', 'was', 'used', 'in', '"', 'very', 'modest', 'amounts', '"', 'in', 'making', 'paper', 'for', 'the', 'filters', 'in', 'the', 'early', '1950s', 'and', 'replaced', 'with', 'a', 'different', 'type', 'of', 'filter', 'in', '1956', '.', 'From', '1953', 'to', '1955', ',', '9', '.', '8', 'billion', 'Kent', 'cigarettes', 'with', 'the', 'filters', 'were', 'sold', ',', 'the', 'company', 'said', '.', 'Among', '33', 'men', 'who', 'worked', 'closely', 'with', 'the', 'substance', ',', '28', 'have', 'died', '--', 'more', 'than', 'three', 'times', 'the', 'expected', 'number', '.', 'Four', 'of', 'the', 'five', 'surviving', 'workers', 'have', 'asbestos', '-', 'related', 'diseases', ',', 'including', 'three', 'with', 'recently', 'diagnosed', 'cancer', '.']
#
# offset : 407
#
# boundaries : {64, 1, 66, 163, 36, 228, 38, 102, 134, 199, 258, 387, 237, 365, 211, 20, 310, 406, 344, 286}

# %%
# 文章から得たトークン
tokens
# Out:
# ['.',
#  'START',
#  'Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'will',
#  'join',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  'Nov',
#  '.',
#  '29',
#  '.',
#  'Mr',
#  '.',
#  'Vinken',
#  'is',
#  'chairman',
#  'of',
#  'Elsevier',
#  'N',
#  '.',
#  'V',
#  '.,',
#  'the',
#  'Dutch',
#  'publishing',
#  'group',
#  '.',
#  '.',
#  'START',
#  'Rudolph',
#  'Agnew',
#  ',',
#  '55',
#  'years',
#  'old',
#  'and',
#  'former',
#  'chairman',
#  'of',
#  'Consolidated',
#  'Gold',
#  'Fields',
#  'PLC',
#  ',',
#  'was',
#  'named',
#  'a',
#  'nonexecutive',
#  'director',
#  'of',
#  'this',
#  'British',
#  'industrial',
#  'conglomerate',
#  '.',
#  '.',
#  'START',
#  'A',
#  'form',
#  'of',
#  'asbestos',
#  'once',
#  'used',
#  'to',
#  'make',
#  'Kent',
#  'cigarette',
#  'filters',
#  'has',
#  'caused',
#  'a',
#  'high',
#  'percentage',
#  'of',
#  'cancer',
#  'deaths',
#  'among',
#  'a',
#  'group',
#  'of',
#  'workers',
#  'exposed',
#  'to',
#  'it',
#  'more',
#  'than',
#  '30',
#  'years',
#  'ago',
#  ',',
#  'researchers',
#  'reported',
#  '.',
#  'The',
#  'asbestos',
#  'fiber',
#  ',',
#  'crocidolite',
#  ',',
#  'is',
#  'unusually',
#  'resilient',
#  'once',
#  'it',
#  'enters',
#  'the',
#  'lungs',
#  ',',
#  'with',
#  'even',
#  'brief',
#  'exposures',
#  'to',
#  'it',
#  'causing',
#  'symptoms',
#  'that',
#  'show',
#  'up',
#  'decades',
#  'later',
#  ',',
#  'researchers',
#  'said',
#  '.',
#  'Lorillard',
#  'Inc',
#  '.,',
#  'the',
#  'unit',
#  'of',
#  'New',
#  'York',
#  '-',
#  'based',
#  'Loews',
#  'Corp',
#  '.',
#  'that',
#  'makes',
#  'Kent',
#  'cigarettes',
#  ',',
#  'stopped',
#  'using',
#  'crocidolite',
#  'in',
#  'its',
#  'Micronite',
#  'cigarette',
#  'filters',
#  'in',
#  '1956',
#  '.',
#  'Although',
#  'preliminary',
#  'findings',
#  'were',
#  'reported',
#  'more',
#  'than',
#  'a',
#  'year',
#  'ago',
#  ',',
#  'the',
#  'latest',
#  'results',
#  'appear',
#  'in',
#  'today',
#  "'",
#  's',
#  'New',
#  'England',
#  'Journal',
#  'of',
#  'Medicine',
#  ',',
#  'a',
#  'forum',
#  'likely',
#  'to',
#  'bring',
#  'new',
#  'attention',
#  'to',
#  'the',
#  'problem',
#  '.',
#  'A',
#  'Lorillard',
#  'spokewoman',
#  'said',
#  ',',
#  '"',
#  'This',
#  'is',
#  'an',
#  'old',
#  'story',
#  '.',
#  'We',
#  "'",
#  're',
#  'talking',
#  'about',
#  'years',
#  'ago',
#  'before',
#  'anyone',
#  'heard',
#  'of',
#  'asbestos',
#  'having',
#  'any',
#  'questionable',
#  'properties',
#  '.',
#  'There',
#  'is',
#  'no',
#  'asbestos',
#  'in',
#  'our',
#  'products',
#  'now',
#  '."',
#  'Neither',
#  'Lorillard',
#  'nor',
#  'the',
#  'researchers',
#  'who',
#  'studied',
#  'the',
#  'workers',
#  'were',
#  'aware',
#  'of',
#  'any',
#  'research',
#  'on',
#  'smokers',
#  'of',
#  'the',
#  'Kent',
#  'cigarettes',
#  '.',
#  '"',
#  'We',
#  'have',
#  'no',
#  'useful',
#  'information',
#  'on',
#  'whether',
#  'users',
#  'are',
#  'at',
#  'risk',
#  ',"',
#  'said',
#  'James',
#  'A',
#  '.',
#  'Talcott',
#  'of',
#  'Boston',
#  "'",
#  's',
#  'Dana',
#  '-',
#  'Farber',
#  'Cancer',
#  'Institute',
#  '.',
#  'Dr',
#  '.',
#  'Talcott',
#  'led',
#  'a',
#  'team',
#  'of',
#  'researchers',
#  'from',
#  'the',
#  'National',
#  'Cancer',
#  'Institute',
#  'and',
#  'the',
#  'medical',
#  'schools',
#  'of',
#  'Harvard',
#  'University',
#  'and',
#  'Boston',
#  'University',
#  '.',
#  'The',
#  'Lorillard',
#  'spokeswoman',
#  'said',
#  'asbestos',
#  'was',
#  'used',
#  'in',
#  '"',
#  'very',
#  'modest',
#  'amounts',
#  '"',
#  'in',
#  'making',
#  'paper',
#  'for',
#  'the',
#  'filters',
#  'in',
#  'the',
#  'early',
#  '1950s',
#  'and',
#  'replaced',
#  'with',
#  'a',
#  'different',
#  'type',
#  'of',
#  'filter',
#  'in',
#  '1956',
#  '.',
#  'From',
#  '1953',
#  'to',
#  '1955',
#  ',',
#  '9',
#  '.',
#  '8',
#  'billion',
#  'Kent',
#  'cigarettes',
#  'with',
#  'the',
#  'filters',
#  'were',
#  'sold',
#  ',',
#  'the',
#  'company',
#  'said',
#  '.',
#  'Among',
#  '33',
#  'men',
#  'who',
#  'worked',
#  'closely',
#  'with',
#  'the',
#  'substance',
#  ',',
#  '28',
#  'have',
#  'died',
#  '--',
#  'more',
#  'than',
#  'three',
#  'times',
#  'the',
#  'expected',
#  'number',
#  '.',
#  'Four',
#  'of',
#  'the',
#  'five',
#  'surviving',
#  'workers',
#  'have',
#  'asbestos',
#  '-',
#  'related',
#  'diseases',
#  ',',
#  'including',
#  'three',
#  'with',
#  'recently',
#  'diagnosed',
#  'cancer',
#  '.']

# %%
# 文章の長さ
offset
# Out:
# 407

# %%
# 今回取得した文章は20個
len(boundaries)
# Out:
# 20

# %%
# 文章が終了する際のtokensにおける添え字の位置
boundaries
# Out:
# {1,
#  20,
#  36,
#  38,
#  64,
#  66,
#  102,
#  134,
#  163,
#  199,
#  211,
#  228,
#  237,
#  258,
#  286,
#  310,
#  344,
#  365,
#  387,
#  406}

# %%
# 素性抽出器
def punct_features(tokens, i):
    return {'next-word-capitalized': tokens[i+1][0].isupper(), # 句読点の次の単語が大文字かどうか
            'prev-word': tokens[i-1].lower(), # 句読点の前の単語を小文字化
            'punct': tokens[i], # 句読点
            'prev-word-is-one-char': len(tokens[i-1]) == 1} # 前の単語が一文字かどうか

# %%
# 特徴量を取得
# リスト内包表記
featuresets = [(punct_features(tokens, i), (i in boundaries))
               for i in range(1, len(tokens)-1)
               if tokens[i] in '.?!']

# %%
len(featuresets)
# Out:
# 24

# %%
featuresets
# Out:
# [({'next-word-capitalized': False,
#    'prev-word': 'nov',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': '29',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'mr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'n',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'group',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': False,
#    'prev-word': 'conglomerate',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '.',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'reported',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'corp',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': '1956',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'problem',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'story',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'properties',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': 'cigarettes',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'a',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'institute',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'dr',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'university',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': '1956',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': False,
#    'prev-word': '9',
#    'prev-word-is-one-char': True,
#    'punct': '.'},
#   False),
#  ({'next-word-capitalized': True,
#    'prev-word': 'said',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True),
#  ({'next-word-capitalized': True,
#    'prev-word': 'number',
#    'prev-word-is-one-char': False,
#    'punct': '.'},
#   True)]
